# %%
import pickle
profit=pickle.load(open('/content/Finalized_model_MLR_profit_prediction.sav','rb'))
r_d = float(input("Enter the R&D Spend : "))
administration = float(input("Enter the Administration : "))
MarketingSpend = float(input("Enter the Marketing Spend : "))
State_Florida = int(input("Enter the  State_Florida : "))
State_NewYork = int(input("Enter the State_New York : "))
print()
sol=profit.predict([[r_d,administration,MarketingSpend,State_Florida,State_NewYork]])[0][0]
print(f"The profit is : {sol:.2f}")
# Out:
# Enter the R&D Spend : 245785.76
# Enter the Administration : 479536.97
# Enter the Marketing Spend : 457805.85
# Enter the  State_Florida : 0
# Enter the State_New York : 0
#
# The profit is : 245315.22
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
